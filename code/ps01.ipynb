# %% [markdown]
# # Meg McCauley,
# Signals and Systems,
# Problem Set 01,
# January 29, 2015

# %%
from __future__ import print_function, division

import thinkdsp
import thinkplot

# %matplotlib inline

# %% [markdown]
# ## Question 1

# %% [markdown]
# Make a recording of an interesting sound as a WAV file, or go to freesound.org and find one.  Load it and play it from IPython.

# %%
wave = thinkdsp.read_wave('Analog23.wav')
wave.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
wave.plot()

# %% [markdown]
# Here is the entirety of my sound plotted. It is called Analog23.wav and it was sourced from http://www.freesound.org/people/junggle/sounds/31246/.
# It is some kind of electronic music that incorporates a flute.

# %% [markdown]
# ## Question 2

# %% [markdown]
# Select a short segment of a waveform and plot it.  See if you can find a segment that shows a few cycles of a periodic signal.  Does it look like a sinusoid or mixture of sinusoids?

# %%
start = 1.1
duration = 1
segment = wave.segment(start, duration)
segment.plot()

# %% [markdown]
# I looked for a signal that included repetitive periodic cycles.The majority of the wave does look sinusoidal, particularly between 0.2 and 0.4. There are other sinusoidal patterns of differing size and length throughout the segment.

# %% [markdown]
# ## Question 3

# %% [markdown]
# Compute and plot the spectrum of at least one segment of the wave.  Describe the harmonic structure, if any.

# %%
spectrum = segment.make_spectrum()
spectrum.plot()

# %%
spectrum.plot(low=500, high=2500)

# %% [markdown]
# The first plot is plot of the entire segment and the second plot is a zoomed in version to focus on where the frequencies are. The dominant can be seen at around 1000 Hz. Because all of the frequencies occur between 1000 Hz and 1500 Hz, there are no harmonics created.

# %% [markdown]
# ## Question 4

# %% [markdown]
# Apply a few different filters to the segment (or the whole wave) and listen to the effect.  Try a low pass, high pass, and band-stop filter.  Try some different cutoff frequencies.

# %%
segment.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# High Pass Filter

# %%
spectrum = segment.make_spectrum()
spectrum.high_pass(2000)
spectrum.plot()

# %%
filtered = spectrum.make_wave()
filtered.normalize()
filtered.apodize()
filtered.plot()

# %%
filtered.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Low Pass Filter

# %%
spectrum = segment.make_spectrum()
spectrum.low_pass(1000)
spectrum.plot()

# %%
filtered = spectrum.make_wave()
filtered.normalize()
filtered.apodize()
filtered.plot()

# %%
filtered.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Band-Stop Filter

# %%
bs_spectrum = segment.make_spectrum()
bs_spectrum.band_stop(1100,1900)
bs_spectrum.plot()

# %%
filtered = bs_spectrum.make_wave()
filtered.normalize()
filtered.apodize()
filtered.plot()

# %%
filtered.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# I first created an audio clip with the original segment, for comparison sake. Then, I created segments filtered with a high pass filter and a low pass filter. Each time, I ploted the filtered segment and created an audio clip.
#
# I played around with different cutoff frequencies and found the ones displayed here were able to show the differences in filtering to both the eyes and the ears.

# %% [markdown]
# ## Question 5

# %% [markdown]
# Synthesize a wave by creating a spectrum with arbitrary harmonics, invoking *make_wave*, and listening. What happens as you add frequency components that are not multiples of the fundamental?

# %%
harm1 = thinkdsp.CosSignal(freq=550, amp=1, offset=0)
harm2 = thinkdsp.CosSignal(freq=1100, amp=1, offset=0)

# %%
total_sig = harm1 + harm2
total_sig.plot()

# %%
wave_hi = total_sig.make_wave(duration=.5, start=0, framerate=11025)
wave_hi.plot()

# %%
wave_hi.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
harm3 = thinkdsp.CosSignal(freq=1800, amp=1, offset=0)
total_sig += harm3
total_sig.plot()

# %%
wave_out = total_sig.make_wave(duration=.5, start=0, framerate=11025)
wave_out.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# When you add frequency components that are not multiples of the fundamental, it makes the audio less pure and more dissonant.

# %% [markdown]
# ## Question 6

# %% [markdown]
# Write a class called SawtoothSignal that extends Signal and provides evaluate to evaluate a sawtooth signal.

# %%
class SawtoothSignal(thinkdsp.Sinusoid):
    def evaluate(self,ts):
        T = self.period  # Automatically takes the frequency and calculates the period (from Sinusoid)
        return (((((ts-self.offset)%T)/T)*2)-1)*self.amp

# %% [markdown]
# Subtracting self.offset moves the wave to the right
#
# T is 1/frequency (aka period)
#
# %T creates the stop at the top and the jump down to the bottom to restart
#
# Dividing by T changes the Y scale
#
# Multiplying by 2 and then subtracting 1 changes the Y scale to go from -1 to 1
#
# Multiplying by self.amp deals with the amplitude up and down scaling

# %% [markdown]
# ## Question 7

# %% [markdown]
# Compute the spectrum of a sawtooth wave. How does the harmonic structure compare to triangle and square waves?

# %% [markdown]
# Sawtooth Signal and Spectrum

# %%
sawsig = SawtoothSignal(freq=500)
sawsig.plot()

# %%
wav = sawsig.make_wave()
sawspec = wav.make_spectrum()
sawspec.plot()

# %% [markdown]
# The fundamental frequency of the sawtooth wave is at 500 Hz. Each subsequent frequency occurs at an increase of 500 Hz. It has an odd and even harmonic structure (1, 2, 3, 4...). The function of the dropoff can be approximated by $y = 1/x$. This can be determined because the second peak is 1/2 of the first peak, the third peak is 1/3, etc.

# %% [markdown]
# Triangle Signal and Spectrum

# %%
tri = thinkdsp.TriangleSignal(freq=500)
tri.plot()

# %%
triwave = tri.make_wave()
trispec = triwave.make_spectrum()
trispec.plot()

# %% [markdown]
# The fundamental frequency of the triangle wave is also at 500 Hz. Each subsequent frequency occurs at an increase of 1000 Hz. It has an odd harmonic structure (1, 3, 5, 7...). The dropoff is much more dramatic and has a much faster decrease. It can be approximated by the function $y = 1/f^2$.

# %% [markdown]
# Square Signal and Spectrum

# %%
square = thinkdsp.SquareSignal(freq=500)
square.plot()

# %%
squwave = square.make_wave()
squspec = squwave.make_spectrum()
squspec.plot()

# %% [markdown]
# The fundamental frequency of the square wave is at 500 Hz like both the sawtooth and triangle waves. Each subsequent frequency occurs at an increase of 1000 Hz. It has an odd harmonic structure (1, 3, 5, 7...). The dropoff can be approximated by the function $y = 1/f$.

# %% [markdown]
# ## Question 8

# %% [markdown]
# Sample an 1100 Hz triangle at 10000 frames per second and listen to it. Can you hear the aliased harmonic? It might help if you play a sequence of notes with increasing pitch.

# %%
trihard = thinkdsp.TriangleSignal(1100)
triwave = trihard.make_wave(duration=0.01, framerate=10000)
triwave.apodize()
triwave.plot()

# %%
trispec = triwave.make_spectrum()
trispec.plot()

# %%
triwave = trihard.make_wave(duration=3, framerate=10000)
triwave.apodize()
triwave.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Question 9

# %% [markdown]
# Compute the spectrum of an 1100 Hz square wave sampled at 10 kHz, and compare it to the spectrum of a triangle wave in Figure 2.5

# %%
square = thinkdsp.SquareSignal(freq=1100)
sqwave = square.make_wave(duration=2, framerate=10000)
sqwave.apodize()
sqwave.plot()

# %%
sqspec = sqwave.make_spectrum()
sqspec.plot()

# %% [markdown]
# Compared to the spectrum in Figure 2.5, the square wave spectrum here has the same issue of losing information. This is because of the high frequency and the measurements at discrete time steps. You can see similarities in the way that both third peaks do not reach as high on the y axis as they should to fit the expected frequencies.

# %% [markdown]
# ## Question 10

# %% [markdown]
# The triangle and square waves have odd harmonics only; the sawtooth wave has both even and odd harmonics. The harmonics of the square and sawtooth waves drop off in proportion to $1/f$; the harmonics of the triangle wave drop off like $1/f^2$. Can you find a waveform that has even and odd harmonics that drop off like $1/f^2$?

# %%
sinwav = []
for i in range(5):
    sinwav.append(thinkdsp.SinSignal(freq = 440+440*i, amp = (1/(i+1))/(i+1)))
wav_tot = sum(sinwav)
wav_tot.plot()

# %%
wav_tot.make_wave().make_spectrum().plot()

# %% [markdown]
# I created a representation of the signal using five subsignal sin waves.
#
# I set the frequency to increase by a multiple of 440 each time a new signal was created.
#
# Because the drop off was supposed to be $1/f^2$, I worked with the amplitude to change height of the peaks in relationship to the number of each signal.
#
# I didn't change the offset because it was not needed.
